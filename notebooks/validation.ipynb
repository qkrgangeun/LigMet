# %%
import pandas as pd
import re

# 파일 경로
val_pdb_path = "/home/qkrgangeun/LigMet/code/text/biolip/filtered/val_pdbs_filtered.txt"
metal_site_path = "/home/qkrgangeun/LigMet/code/text/biolip/metal_binding_sites_NOSSE.csv"

# 표준 아미노산 정의
standard_aas = {
    'ALA', 'ARG', 'ASN', 'ASP', 'CYS', 'GLN', 'GLU', 'GLY', 'HIS', 'ILE',
    'LEU', 'LYS', 'MET', 'PHE', 'PRO', 'SER', 'THR', 'TRP', 'TYR', 'VAL'
}

# metal site가 standard인지 판단
def is_standard_site(binding_str):
    residues = re.findall(r"'(\w+)'", binding_str)
    return all(res in standard_aas for res in residues)

# 1. validation pdb 리스트
with open(val_pdb_path, "r") as f:
    val_pdbs = set(line.strip().lower() for line in f if line.strip())

# 2. metal site 정보
df = pd.read_csv(metal_site_path)
df["pdb_id"] = df["PDB ID"].str.lower()
df = df[df["pdb_id"].isin(val_pdbs)]
df["is_standard"] = df["Binding Residues"].apply(is_standard_site)

# 3. PDB별 site 구성을 기반으로 그룹 나누기
group_a, group_b, group_c = [], [], []

pdb_to_sites = df.groupby("pdb_id")["is_standard"].apply(list)

for pdb_id, flags in pdb_to_sites.items():
    if all(flags):
        group_a.append(pdb_id)
    elif any(flags):
        group_b.append(pdb_id)
    else:
        group_c.append(pdb_id)

# 4. 결과 출력
print("✔ Group A (standard-only):", group_a)
print("✔ Group B (mixed):", group_b)
print("✔ Group C (ligand-only):", group_c)
# Out:
# ✔ Group A (standard-only): ['5xwm', '5ya6', '5z34', '5z6e', '5zns', '5znt', '5zo4', '5zo5', '5zru', '5zt7', '6a2w', '6a48', '6a8z', '6a93', '6a94', '6aef', '6ai0', '6bt9', '6c72', '6ck1', '6cmk', '6cnl', '6cpt', '6cpu', '6cqg', '6cxb', '6d2s', '6d2y', '6d9f', '6ddt', '6ddu', '6dk9', '6dkc', '6dkd', '6dtk', '6dyo', '6e60', '6e61', '6e90', '6edw', '6eet', '6elt', '6elv', '6f98', '6fhg', '6fok', '6fop', '6foy', '6fp5', '6fpy', '6frw', '6gel', '6gez', '6gf7', '6gka', '6gkb', '6gkc', '6goc', '6gos', '6gpx', '6grg', '6grh', '6gri', '6gs8', '6guu', '6gux', '6guy', '6guz', '6h3a', '6h4l', '6h5k', '6h5m', '6h5u', '6h6n', '6h6o', '6h6p', '6h7t', '6h87', '6h98', '6h99', '6hb0', '6hbd', '6hbe', '6hbm', '6hbs', '6hbv', '6hcz', '6hd2', '6hft', '6hk5', '6hk9', '6hkv', '6hpd', '6hq4', '6hq7', '6hqv', '6hr1', '6hr5', '6htj', '6hur', '6hus', '6hwj', '6hyh', '6hzn', '6hzz', '6i01', '6i02', '6i1q', '6i1t', '6i5r', '6i5w', '6i7s', '6i9h', '6iah', '6ibh', '6ibi', '6ibj', '6idy', '6ie3', '6ifc', '6iff', '6ifq', '6iie', '6iih', '6ijm', '6ijp', '6il9', '6ilb', '6imq', '6iqq', '6ir0', '6ist', '6iu3', '6iu4', '6iu5', '6iu6', '6iu8', '6iu9', '6iuy', '6iv5', '6iw6', '6iy8', '6iym', '6iz2', '6j07', '6j0d', '6j23', '6j2l', '6j4b', '6j4c', '6j4n', '6j4t', '6j7n', '6j7o', '6j7r', '6j7s', '6j98', '6jau', '6jde', '6jdk', '6jds', '6jja', '6jkw', '6jl9', '6jmt', '6jmz', '6jn0', '6jn1', '6jn8', '6jni', '6jp4', '6jph', '6jpn', '6jre', '6jtf', '6jtt', '6jtu', '6jtz', '6ju8', '6ju9', '6jv6', '6jx3', '6jzb', '6k0m', '6k0n', '6k0p', '6k0q', '6k0s', '6k0u', '6k0v', '6k15', '6k18', '6k1a', '6k1b', '6k1d', '6k1e', '6k31', '6k4e', '6k7k', '6k7l', '6k7m', '6k7n', '6k82', '6k83', '6k85', '6k86', '6k88', '6k89', '6k8a', '6k8b', '6k8n', '6k8o', '6kaj', '6kak', '6kam', '6kan', '6kcv', '6kcw', '6khu', '6kkt', '6klc', '6kld', '6kle', '6klh', '6koy', '6koz', '6kp0', '6kp1', '6kq1', '6ksy', '6ktv', '6ktw', '6ktx', '6ktz', '6ku1', '6ku2', '6kvw', '6kvy', '6kvz', '6kw0', '6kwa', '6kz8', '6kzk', '6kzp', '6l5t', '6l7s', '6l7t', '6l7u', '6l7w', '6l8n', '6l99', '6leb', '6lhd', '6ljc', '6ljd', '6lnd', '6lnh', '6lp1', '6lrb', '6lth', '6lvb', '6lvc', '6lx1', '6lxs', '6lxt', '6lxx', '6m1w', '6m27', '6m32', '6m3y', '6m48', '6m5a', '6m5r', '6m5s', '6m5u', '6m5v', '6m6r', '6m6s', '6m77', '6m8r', '6m9s', '6md3', '6mf4', '6mlt', '6mm1', '6mmo', '6ms4', '6mtw', '6mvg', '6mvh', '6mzb', '6n1b', '6n29', '6n2m', '6nbb', '6nff', '6njc', '6njv', '6noz', '6nph', '6npl', '6nsi', '6ntf', '6nur', '6nus', '6nvo', '6nvp', '6nwz', '6nz0', '6o5k', '6o5o', '6o6j', '6o7c', '6o7g', '6o9n', '6oae', '6oap', '6oaq', '6ob8', '6oec', '6ogh', '6ohh', '6oii', '6ok1', '6okh', '6omp', '6omq', '6omr', '6on1', '6org', '6ori', '6otf', '6ov6', '6ov8', '6ovf', '6own', '6p16', '6p1g', '6p2k', '6p3x', '6p3y', '6p3z', '6p40', '6p4f', '6p7o', '6pbc', '6pd1', '6pfz', '6pii', '6pmg', '6pmp', '6pqn', '6pqr', '6pqu', '6pt9', '6pup', '6pv0', '6pv1', '6pv2', '6pv3', '6pv4', '6pw7', '6pwj', '6pyo', '6pyx', '6q09', '6q2j', '6q3m', '6q63', '6q6b', '6qaj', '6qe7', '6qga', '6qgb', '6qj6', '6qk5', '6qps', '6qta', '6qtb', '6qu1', '6qvm', '6qwo', '6qxz', '6qz1', '6qz3', '6qz4', '6r1g', '6r3r', '6r3u', '6ra0', '6rbf', '6rcz', '6rej', '6rek', '6ric', '6rim', '6rjy', '6rkh', '6rkj', '6rkl', '6rkx', '6rl1', '6rl2', '6rmr', '6rn5', '6rp4', '6rre', '6rv5', '6rwg', '6rxd', '6rxf', '6rxg', '6ryv', '6ryw', '6ryx', '6s0p', '6s63', '6s6c', '6s7e', '6scp', '6sg8', '6sj0', '6sj1', '6sjw', '6sjx', '6sl2', '6sl3', '6slo', '6sna', '6son', '6soo', '6soq', '6sor', '6sus', '6t0q', '6t4d', '6t72', '6tcb', '6thh', '6tl0', '6tlx', '6tly', '6tm2', '6tm6', '6tnh', '6tnj', '6tp5', '6tr3', '6tr4', '6ty0', '6ty2', '6tyj', '6tzy', '6tzz', '6u08', '6u19', '6u2m', '6u4b', '6u7l', '6u9v', '6u9w', '6uas', '6uat', '6uax', '6uca', '6uco', '6ucp', '6ukn', '6umt', '6unc', '6upd', '6uts', '6uvx', '6uw1', '6uw7', '6uwa', '6uxu', '6v1s', '6v4c', '6v4s', '6v55', '6v81', '6v85', '6v86', '6v98', '6v9p', '6v9q', '6v9v', '6v9w', '6vbw', '6vcg', '6vch', '6vd8', '6vda', '6vgc', '6vhf', '6vj ...
# ✔ Group B (mixed): ['6bs3', '6dka', '6g7o', '6gpz', '6h59', '6h5a', '6ick', '6icl', '6icm', '6icn', '6ico', '6icp', '6icq', '6ifg', '6j7t', '6jon', '6jop', '6joq', '6jwq', '6jwr', '6jws', '6jwt', '6jwu', '6jwv', '6jww', '6jwx', '6jwy', '6jwz', '6k9a', '6kal', '6kck', '6kcl', '6kcm', '6klg', '6kli', '6klj', '6kvo', '6kwb', '6m0x', '6m2i', '6mdw', '6mdx', '6n1a', '6no0', '6no1', '6o3p', '6pr5', '6puq', '6qdi', '6qfd', '6qil', '6ren', '6rid', '6rtg', '6sj4', '6thk', '6tmt', '6to1', '6uw3', '6uw5', '6v93', '6wis', '6wje', '6wn3', '6wnb', '6wnc', '6wnd', '6wo0', '6x0o', '6x67', '6x68', '6y8s', '6yav', '6yii', '6z2q', '6zpb', '7aap', '7c8z', '7ck2', '7d4o', '7d4s', '7d8g', '7d8l', '7d8q']
# ✔ Group C (ligand-only): ['5s8q', '5zri', '6a6j', '6ae9', '6bs4', '6cbs', '6cbt', '6d71', '6d9m', '6dq3', '6fm1', '6g7d', '6gtp', '6gtr', '6hq5', '6hwl', '6hz4', '6i5s', '6ia7', '6ian', '6ie2', '6ih1', '6ih7', '6ila', '6imc', '6iuc', '6izv', '6j66', '6j72', '6jil', '6jki', '6jmg', '6jmx', '6jmy', '6jn7', '6jrf', '6jrg', '6jt2', '6jt5', '6jtg', '6jwf', '6k6t', '6kbj', '6kbq', '6kc2', '6khy', '6ki3', '6ksa', '6kv1', '6l54', '6l7v', '6li7', '6lik', '6lpp', '6lpq', '6lpt', '6lpu', '6lpx', '6ltr', '6ltu', '6m0v', '6m0w', '6m29', '6m2h', '6m9r', '6mm2', '6n63', '6n7e', '6n7i', '6n7n', '6n7s', '6n7t', '6n7v', '6nef', '6no2', '6no3', '6no5', '6ofb', '6oh6', '6on2', '6on4', '6os6', '6p3i', '6p4u', '6p8j', '6pd2', '6pek', '6pen', '6ph4', '6pqx', '6pt4', '6pt6', '6ptk', '6pwk', '6qeb', '6qp0', '6qrj', '6qw5', '6qzk', '6r4g', '6r4j', '6r9n', '6rm2', '6rme', '6rmw', '6roh', '6roi', '6roj', '6s21', '6s48', '6s83', '6sj2', '6sj3', '6sko', '6srt', '6ssc', '6su5', '6sul', '6sum', '6sun', '6svm', '6svp', '6syt', '6t1d', '6tqe', '6tqf', '6tt8', '6tta', '6ttc', '6ty9', '6tz2', '6u43', '6u44', '6u45', '6uk1', '6ukh', '6uki', '6upc', '6upe', '6ut3', '6ut4', '6ut5', '6ut6', '6ut8', '6vii', '6vij', '6vkz', '6vl0', '6vzq', '6vzs', '6vzw', '6w04', '6w25', '6wb6', '6wdz', '6we0', '6we1', '6wmm', '6wmn', '6wmo', '6xjh', '6xji', '6xmq', '6y4e', '6y9c', '6yb9', '6ymw', '6ywn', '6z2o', '6z3r', '6z74', '6za0', '6za7', '6zab', '6zii', '7bxo', '7bz0', '7c1z', '7cv2', '7cxz', '7d8i', '7dic', '7did', '7dol', '7dsj', '7jhi', '7jhl', '7jhn', '7jho', '7kjc', '7lvv']

# %%
import re
import numpy as np

# 1. 그룹 A, B, C의 pdb 리스트 (소문자)
# group_a = ['6kq1']
# group_b = []
# group_c = ['6y4f']

# 2. 로그 파일 경로
log_path = "/home/qkrgangeun/LigMet/benchmark/test_chain1_pre3.log"

# 3. 로그에서 성능 파싱
results = {}  # {pdb_id: {'precision': x, 'recall': y, 'type_accuracy': z}}

with open(log_path, 'r') as f:
    lines = f.readlines()

pdb_id = None
for line in lines:
    pdb_match = re.match(r"=== PDB: \['(\w+)'\] ===", line)
    if pdb_match:
        pdb_id = pdb_match.group(1).lower()
        results[pdb_id] = {}

    if pdb_id and "threshold 0.5 | precision:" in line:
        pr, rc = re.findall(r"precision: ([0-9.]+) \| recall: ([0-9.]+)", line)[0]
        results[pdb_id]["precision"] = float(pr)
        results[pdb_id]["recall"] = float(rc)

    if pdb_id and "threshold 0.5 | type_accuracy:" in line:
        acc = re.findall(r"type_accuracy: ([0-9.]+)", line)[0]
        results[pdb_id]["type_accuracy"] = float(acc)

# 4. 그룹별 성능 평균 계산
def group_avg(group_ids, group_name):
    precisions = [results[pdb]["precision"] for pdb in group_ids if pdb in results]
    recalls = [results[pdb]["recall"] for pdb in group_ids if pdb in results]
    accs = [results[pdb]["type_accuracy"] for pdb in group_ids if pdb in results]
    print(f"\n📊 {group_name} (PDB 수: {len(precisions)}):")
    print(f"  - Precision (threshold 0.5): {np.mean(precisions):.4f}")
    print(f"  - Recall (threshold 0.5): {np.mean(recalls):.4f}")
    print(f"  - Type Accuracy (threshold 0.5): {np.mean(accs):.4f}")

# 5. 출력
group_avg(group_a, "Group A - standard-only")
group_avg(group_b, "Group B - mixed")
group_avg(group_c, "Group C - ligand-only")
# Out:
# 📊 Group A - standard-only (PDB 수: 651):
#   - Precision (threshold 0.5): 0.3687
#   - Recall (threshold 0.5): 0.7051
#   - Type Accuracy (threshold 0.5): 0.7260
#
# 📊 Group B - mixed (PDB 수: 84):
#   - Precision (threshold 0.5): 0.4472
#   - Recall (threshold 0.5): 0.8264
#   - Type Accuracy (threshold 0.5): 0.6458
#
# 📊 Group C - ligand-only (PDB 수: 191):
#   - Precision (threshold 0.5): 0.4061
#   - Recall (threshold 0.5): 0.8147
#   - Type Accuracy (threshold 0.5): 0.7392

# %%
import pandas as pd
import re

# 경로
log_path = "/home/qkrgangeun/LigMet/benchmark/test_chain1_pre3.log"
metal_site_path = "/home/qkrgangeun/LigMet/code/text/biolip/metal_binding_sites_NOSSE.csv"

# 🎯 Group A 리스트를 실제 PDB ID로 설정
# group_a = ['6kq1', '6y4f']  # ← 여기에 실제 Group A의 pdb_id 소문자 목록 입력

# 1. 로그에서 precision / recall 추출
results = {}
with open(log_path, 'r') as f:
    lines = f.readlines()

pdb_id = None
for line in lines:
    match = re.match(r"=== PDB: \['(\w+)'\] ===", line)
    if match:
        pdb_id = match.group(1).lower()
        results[pdb_id] = {}
    if pdb_id and "threshold 0.5 | precision:" in line:
        pr, rc = re.findall(r"precision: ([0-9.]+) \| recall: ([0-9.]+)", line)[0]
        results[pdb_id]["precision"] = float(pr)
        results[pdb_id]["recall"] = float(rc)

# 2. Group A 중 high_pr / low_pr 분류
high_pr, low_pr = [], []
for pdb in group_a:
    if pdb in results:
        pr, rc = results[pdb]["precision"], results[pdb]["recall"]
        if pr > 0.5 and rc > 0.7:
            high_pr.append(pdb)
        elif pr <= 0.5 and rc <= 0.7:
            low_pr.append(pdb)

# 3. 메탈 사이트 정보 불러오기 및 binding residue 수 계산
df = pd.read_csv(metal_site_path)
df["pdb_id"] = df["PDB ID"].str.lower()
df["num_residues"] = df["Binding Residues"].apply(lambda s: len(re.findall(r"'(\w+)'", s)))

# 4. high_pr / low_pr 필터링 + binding residue ≥ 4 조건
high_df = df[(df["pdb_id"].isin(high_pr)) & (df["num_residues"] >= 3)]
low_df = df[(df["pdb_id"].isin(low_pr)) & (df["num_residues"] >= 3)]

# 5. 저장
high_df.to_csv("nosse_filtered_high_pr.csv", index=False)
low_df.to_csv("nosse_filtered_low_pr.csv", index=False)

print("✔ 파일 저장 완료:")
print(" - nosse_filtered_high_pr.csv (binding residues >= 3)")
print(" - nosse_filtered_low_pr.csv (binding residues >= 3)")
# Out:
# ✔ 파일 저장 완료:
#  - nosse_filtered_high_pr.csv (binding residues > 3)
#  - nosse_filtered_low_pr.csv (binding residues > 3)
